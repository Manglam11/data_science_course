# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Data structure: [restaurant_id, 2021, 2022, 2023, 2024]
sales_data = np.array([
    [1, 150000, 180000, 220000, 250000],  # Paradise Biryani
    [2, 120000, 140000, 160000, 190000],  # Beijing Bites
    [3, 200000, 230000, 260000, 300000],  # Pizza Hub
    [4, 180000, 210000, 240000, 270000],  # Burger Point
    [5, 160000, 185000, 205000, 230000]   # Chai Point
])

# %%
print(sales_data.shape)
print(sales_data[:,1:])
# Out:
# (5, 5)
# [[150000 180000 220000 250000]
#  [120000 140000 160000 190000]
#  [200000 230000 260000 300000]
#  [180000 210000 240000 270000]
#  [160000 185000 205000 230000]]

# %%
print(np.sum(sales_data, axis=0))
print(np.sum(sales_data[:,1:], axis=0))
# Out:
# [     15  810000  945000 1085000 1240000]
# [ 810000  945000 1085000 1240000]

# %%
min_sales = np.min(sales_data[:,1:], axis=1)
print(min_sales)
# Out:
# [150000 120000 200000 180000 160000]

# %%
max_sales = np.max(sales_data[:,1:], axis=0)
print(max_sales)
# Out:
# [200000 230000 260000 300000]

# %%
avg_sales = np.mean(sales_data[:, 1:], axis=1)
print(avg_sales)
# Out:
# [200000. 152500. 247500. 225000. 195000.]

# %%
cumsum = np.cumsum(sales_data[:,1:], axis=1)
print(cumsum)

plt.figure(figsize=(10,6))
plt.plot(np.mean(cumsum, axis=0))
plt.title("Average cumilitive sales accross all restuarant")
plt.xlabel("Years")
plt.ylabel("Sales")
plt.grid(True)
plt.show()
# Out:
# [[150000 330000 550000 800000]
#  [120000 260000 420000 610000]
#  [200000 430000 690000 990000]
#  [180000 390000 630000 900000]
#  [160000 345000 550000 780000]]

# %%
vector_1 = np.arange(1, 6)
vector_2 = np.arange(6,11)
print(vector_1+vector_2)
print(vector_1*vector_2)
print(np.dot(vector_1,vector_2)) 
angle = np.arccos(np.dot(vector_1,vector_2)/(np.linalg.norm(vector_1)*np.linalg.norm(vector_2)))

print(angle)
# Out:
# [ 7  9 11 13 15]
# [ 6 14 24 36 50]
# 130
# 0.26554161733900966

# %%
rest_type = np.array(["indian", "chinise", "italian","french"])
vectorized_upper = np.vectorize(str.upper)
print(vectorized_upper(rest_type))
# Out:
# ['INDIAN' 'CHINISE' 'ITALIAN' 'FRENCH']

# %%
monthly_avg = sales_data[:, 1:] /12
print(monthly_avg)
# Out:
# [[12500.         15000.         18333.33333333 20833.33333333]
#  [10000.         11666.66666667 13333.33333333 15833.33333333]
#  [16666.66666667 19166.66666667 21666.66666667 25000.        ]
#  [15000.         17500.         20000.         22500.        ]
#  [13333.33333333 15416.66666667 17083.33333333 19166.66666667]]
