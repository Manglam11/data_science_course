# %%
import os
import nltk
# nltk.download()

# %%
# you can also create your own words
AI = '''Artificial Intelligence refers to the intelligence of machines. This is in contrast to the natural intelligence of
humans and animals. With Artificial Intelligence, machines perform functions such as learning, planning, reasoning and
problem-solving. Most noteworthy, Artificial Intelligence is the simulation of human intelligence by machines.
It is probably the fastest-growing development in the World of technology and innovation. Furthermore, many experts believe
AI could solve major challenges and crisis situations.'''

# %%
type(AI)
# Out:
# str

# %%
from nltk.tokenize import word_tokenize
AI_tokens = word_tokenize(AI)
AI_tokens
# Out:
# ['Artificial',
#  'Intelligence',
#  'refers',
#  'to',
#  'the',
#  'intelligence',
#  'of',
#  'machines',
#  '.',
#  'This',
#  'is',
#  'in',
#  'contrast',
#  'to',
#  'the',
#  'natural',
#  'intelligence',
#  'of',
#  'humans',
#  'and',
#  'animals',
#  '.',
#  'With',
#  'Artificial',
#  'Intelligence',
#  ',',
#  'machines',
#  'perform',
#  'functions',
#  'such',
#  'as',
#  'learning',
#  ',',
#  'planning',
#  ',',
#  'reasoning',
#  'and',
#  'problem-solving',
#  '.',
#  'Most',
#  'noteworthy',
#  ',',
#  'Artificial',
#  'Intelligence',
#  'is',
#  'the',
#  'simulation',
#  'of',
#  'human',
#  'intelligence',
#  'by',
#  'machines',
#  '.',
#  'It',
#  'is',
#  'probably',
#  'the',
#  'fastest-growing',
#  'development',
#  'in',
#  'the',
#  'World',
#  'of',
#  'technology',
#  'and',
#  'innovation',
#  '.',
#  'Furthermore',
#  ',',
#  'many',
#  'experts',
#  'believe',
#  'AI',
#  'could',
#  'solve',
#  'major',
#  'challenges',
#  'and',
#  'crisis',
# ...

# %%
len(AI_tokens)
# Out:
# 81

# %%
from nltk.tokenize import sent_tokenize
AI_sent = sent_tokenize(AI)
print(AI_sent)
print(len(AI_sent))
# Out:
# ['Artificial Intelligence refers to the intelligence of machines.', 'This is in contrast to the natural intelligence of\nhumans and animals.', 'With Artificial Intelligence, machines perform functions such as learning, planning, reasoning and\nproblem-solving.', 'Most noteworthy, Artificial Intelligence is the simulation of human intelligence by machines.', 'It is probably the fastest-growing development in the World of technology and innovation.', 'Furthermore, many experts believe\nAI could solve major challenges and crisis situations.']
# 6

# %%
from nltk.tokenize import wordpunct_tokenize
w_p = wordpunct_tokenize(AI)
print(w_p)
print(len(w_p))
# Out:
# ['Artificial', 'Intelligence', 'refers', 'to', 'the', 'intelligence', 'of', 'machines', '.', 'This', 'is', 'in', 'contrast', 'to', 'the', 'natural', 'intelligence', 'of', 'humans', 'and', 'animals', '.', 'With', 'Artificial', 'Intelligence', ',', 'machines', 'perform', 'functions', 'such', 'as', 'learning', ',', 'planning', ',', 'reasoning', 'and', 'problem', '-', 'solving', '.', 'Most', 'noteworthy', ',', 'Artificial', 'Intelligence', 'is', 'the', 'simulation', 'of', 'human', 'intelligence', 'by', 'machines', '.', 'It', 'is', 'probably', 'the', 'fastest', '-', 'growing', 'development', 'in', 'the', 'World', 'of', 'technology', 'and', 'innovation', '.', 'Furthermore', ',', 'many', 'experts', 'believe', 'AI', 'could', 'solve', 'major', 'challenges', 'and', 'crisis', 'situations', '.']
# 85

# %%
from nltk.tokenize import blankline_tokenize
AI_blank = blankline_tokenize(AI)
print(AI_blank)
print(len(AI_blank))
# Out:
# ['Artificial Intelligence refers to the intelligence of machines. This is in contrast to the natural intelligence of\nhumans and animals. With Artificial Intelligence, machines perform functions such as learning, planning, reasoning and\nproblem-solving. Most noteworthy, Artificial Intelligence is the simulation of human intelligence by machines.\nIt is probably the fastest-growing development in the World of technology and innovation. Furthermore, many experts believe\nAI could solve major challenges and crisis situations.']
# 1

# %%
from nltk.tokenize import WhitespaceTokenizer
AI_white = WhitespaceTokenizer().tokenize(AI)
print(AI_white)
print(len(AI_white))
# Out:
# ['Artificial', 'Intelligence', 'refers', 'to', 'the', 'intelligence', 'of', 'machines.', 'This', 'is', 'in', 'contrast', 'to', 'the', 'natural', 'intelligence', 'of', 'humans', 'and', 'animals.', 'With', 'Artificial', 'Intelligence,', 'machines', 'perform', 'functions', 'such', 'as', 'learning,', 'planning,', 'reasoning', 'and', 'problem-solving.', 'Most', 'noteworthy,', 'Artificial', 'Intelligence', 'is', 'the', 'simulation', 'of', 'human', 'intelligence', 'by', 'machines.', 'It', 'is', 'probably', 'the', 'fastest-growing', 'development', 'in', 'the', 'World', 'of', 'technology', 'and', 'innovation.', 'Furthermore,', 'many', 'experts', 'believe', 'AI', 'could', 'solve', 'major', 'challenges', 'and', 'crisis', 'situations.']
# 70

# %%
from nltk.tokenize import wordpunct_tokenize
w_p = wordpunct_tokenize(AI)
print(w_p)
print(len(w_p))
# Out:
# ['Artificial', 'Intelligence', 'refers', 'to', 'the', 'intelligence', 'of', 'machines', '.', 'This', 'is', 'in', 'contrast', 'to', 'the', 'natural', 'intelligence', 'of', 'humans', 'and', 'animals', '.', 'With', 'Artificial', 'Intelligence', ',', 'machines', 'perform', 'functions', 'such', 'as', 'learning', ',', 'planning', ',', 'reasoning', 'and', 'problem', '-', 'solving', '.', 'Most', 'noteworthy', ',', 'Artificial', 'Intelligence', 'is', 'the', 'simulation', 'of', 'human', 'intelligence', 'by', 'machines', '.', 'It', 'is', 'probably', 'the', 'fastest', '-', 'growing', 'development', 'in', 'the', 'World', 'of', 'technology', 'and', 'innovation', '.', 'Furthermore', ',', 'many', 'experts', 'believe', 'AI', 'could', 'solve', 'major', 'challenges', 'and', 'crisis', 'situations', '.']
# 85

# %%
from nltk import bigrams, trigrams, ngrams
# here we imported our modules

# %%
string = "generative ai & agentic ai is automate the industry & more focus on every domain"
# define var in which we want to perform our task
quotes_tokens = nltk.word_tokenize(string)
# first we tokenized our string using word_tokenize. i don't understand the goal behind this step
print(quotes_tokens)
print(len(quotes_tokens))
# print statements to check the execution
# Out:
# ['generative', 'ai', '&', 'agentic', 'ai', 'is', 'automate', 'the', 'industry', '&', 'more', 'focus', 'on', 'every', 'domain']
# 15

# %%
quotes_bigrams = list(nltk.bigrams(quotes_tokens))
# bi means 2 so it will make pair of 2 consecutinve tokens.
quotes_bigrams
# jupytr alsway printt last cell line
# Out:
# [('generative', 'ai'),
#  ('ai', '&'),
#  ('&', 'agentic'),
#  ('agentic', 'ai'),
#  ('ai', 'is'),
#  ('is', 'automate'),
#  ('automate', 'the'),
#  ('the', 'industry'),
#  ('industry', '&'),
#  ('&', 'more'),
#  ('more', 'focus'),
#  ('focus', 'on'),
#  ('on', 'every'),
#  ('every', 'domain')]

# %%
quotes_trigrams = list(nltk.trigrams(quotes_tokens))
# tri means three so now we will get token in  group size of three.
quotes_trigrams
# Out:
# [('generative', 'ai', '&'),
#  ('ai', '&', 'agentic'),
#  ('&', 'agentic', 'ai'),
#  ('agentic', 'ai', 'is'),
#  ('ai', 'is', 'automate'),
#  ('is', 'automate', 'the'),
#  ('automate', 'the', 'industry'),
#  ('the', 'industry', '&'),
#  ('industry', '&', 'more'),
#  ('&', 'more', 'focus'),
#  ('more', 'focus', 'on'),
#  ('focus', 'on', 'every'),
#  ('on', 'every', 'domain')]

# %%
quotes_ngrams = list(nltk.ngrams(quotes_tokens, 5))
quotes_ngrams
# explicitley defining our group size. claude first explain what is real motive of this grams step? why is this necessay?
# Out:
# [('generative', 'ai', '&', 'agentic', 'ai'),
#  ('ai', '&', 'agentic', 'ai', 'is'),
#  ('&', 'agentic', 'ai', 'is', 'automate'),
#  ('agentic', 'ai', 'is', 'automate', 'the'),
#  ('ai', 'is', 'automate', 'the', 'industry'),
#  ('is', 'automate', 'the', 'industry', '&'),
#  ('automate', 'the', 'industry', '&', 'more'),
#  ('the', 'industry', '&', 'more', 'focus'),
#  ('industry', '&', 'more', 'focus', 'on'),
#  ('&', 'more', 'focus', 'on', 'every'),
#  ('more', 'focus', 'on', 'every', 'domain')]

# %%
from nltk.stem import PorterStemmer
# this library is used for stemming means coverting the word into it's root word if possible.
pst = PorterStemmer()
# we created the object of that class
pst.stem("affection")
# using stem emthod we passed the word which we want to stem
# Out:
# 'affect'

# %%
word_to_stem = ["give", "giving", "given", "gave"]
for word in word_to_stem:
    print(word+ ": "+pst.stem(word))
# we practiced with different word again
# Out:
# give: give
# giving: give
# given: given
# gave: gave

# %%
word_to_stem = ["give", "Giving", "given", "gave", "thinking", "loving", "maximum", "manglam"]
for word in word_to_stem:
    print(word+ ": "+pst.stem(word))
# more words to be practiced
# Out:
# give: give
# Giving: give
# given: given
# gave: gave
# thinking: think
# loving: love
# maximum: maximum
# manglam: manglam

# %%
from nltk.stem import LancasterStemmer
lst = LancasterStemmer()
# i don't understand the use of this class? means give become giv what is happning. smae thing happening to other words also.
for word in word_to_stem:
    print(word+ ": "+lst.stem(word))
# Out:
# give: giv
# Giving: giv
# given: giv
# gave: gav
# thinking: think
# loving: lov
# maximum: maxim
# manglam: manglam

# %%
from nltk.stem import SnowballStemmer
sbst = SnowballStemmer("english")
for word in word_to_stem:
    print(word+ ": "+sbst.stem(word))
# snowballstemer i know this. the porterstemer is only for english but this is for other lanuages also.
# Out:
# give: give
# Giving: give
# given: given
# gave: gave
# thinking: think
# loving: love
# maximum: maximum
# manglam: manglam

# %%
from  nltk.stem import wordnet
from nltk.stem import WordNetLemmatizer
word_lem = WordNetLemmatizer()
# i don't understand this pls explain why we are usin gthis.
for word in word_to_stem:
    print(word+ ": "+word_lem.lemmatize(word))
# Out:
# give: give
# Giving: Giving
# given: given
# gave: gave
# thinking: thinking
# loving: loving
# maximum: maximum
# manglam: manglam

# %%
from nltk.corpus import stopwords
stopwords.words("english")
# we are checking how many stops worda are in enlgish using built in corpus stopwords.
# Out:
# ['a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  "he'd",
#  "he'll",
#  'her',
#  'here',
#  'hers',
#  'herself',
#  "he's",
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  "i'd",
#  'if',
#  "i'll",
#  "i'm",
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it'd",
#  "it'll",
#  "it's",
#  'its',
#  'itself',
#  "i've",
#  'just',
#  'll',
#  'm',
#  'ma',
# ...

# %%
len(stopwords.words("english"))
# just gatherirng some data
# Out:
# 198

# %%
len(stopwords.words("tamil"))
# just gatherirng some data
# Out:
# 125

# %%
len(stopwords.words("bengali"))
# just gatherirng some data
# Out:
# 398

# %%
sent = "my name is manglam"
sent_tokens = word_tokenize(sent)
# now we are kind of preparing recipe so first we tokeize the words
sent_tokens
# Out:
# ['my', 'name', 'is', 'manglam']

# %%
for token in sent_tokens:
    print(nltk.pos_tag([token]))
# now we are deriving different parts of speech of sentence. hey the computer is givin like PRP$, NN, VBZ etc which is little bit of tricky if you kind of give me cheet sheet for this to remeber quick than it will be very helpfull
# Out:
# [('my', 'PRP$')]
# [('name', 'NN')]
# [('is', 'VBZ')]
# [('manglam', 'NN')]

# %%
from nltk import ne_chunk

# NE_sent = "The India's president statys in Delhi"
# NE_sent = "The capital of India is New Delhi"
NE_sent = "The capital of India is New Delhi"

NE_tokens = word_tokenize(NE_sent)
NE_tokens
# Out:
# ['The', 'capital', 'of', 'India', 'is', 'New', 'Delhi']

# %%
NE_tags = nltk.pos_tag(NE_tokens)
NE_tags
# in obove step we just do same things of idenfitying differnt parts of speech
# Out:
# [('The', 'DT'),
#  ('capital', 'NN'),
#  ('of', 'IN'),
#  ('India', 'NNP'),
#  ('is', 'VBZ'),
#  ('New', 'NNP'),
#  ('Delhi', 'NNP')]

# %%
# %pip install wordcloud

# %%
# Create a list of word
text=("Python Python Python Matplotlib Matplotlib Seaborn Network Plot Violin Chart Pandas Datascience Wordcloud Spider Radar Parrallel Alpha Color Brewer Density Scatter Barplot Barplot Boxplot Violinplot Treemap Stacked Area Chart Chart Visualization Dataviz Donut Pie Time-Series Wordcloud Wordcloud Sankey Bubble")
# we are going to test our worldcloud skill with this text

# %%
from wordcloud import WordCloud
# we imported out wordcloud class
wordcloud = WordCloud(width=420, height=200, margin=2, background_color='black', colormap="Accent", mode="RGBA").generate(text)
# we created the object wordcloud of WordCloud class and passing the constructor arg such as width, height, margin, bg color, colormap, mode. what is this mode parameter will do and what will happens without this? after this we called the generatae method with attribute of text as text var

# %%
import matplotlib.pyplot as plt
# we imported matplot lib to visualize our word cloud.
plt.imshow(wordcloud, interpolation="quadric")
# wha tis this interploation attribute?
plt.axis("off")
# what is this line for?
plt.margins(x=0, y=0)
# why this line also?
plt.show()
