# %%
import numpy as np

# %%
import pandas as pd

# %%
lables = ["a", "b", "c"]
my_list = [10,20,30]
my_arr = np.array([10,20,30])
my_dict = {"a":10, "b":20, "c":30}

# %%
pd.Series(my_list)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
pd.Series(my_list, index=lables)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series(my_arr)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
pd.Series(my_dict)
# Out:
# a    10
# b    20
# c    30
# dtype: int64
