# %%
import numpy as np
import pandas as pd

# %%
data = {
    "Name": ["Ram", "Mohan", "Sonu", "Bhola"],
    "Age": [20, 23, 21, 22],
    "City": ["Raipur", "Bhilai", "Jaipur", "Rishikesh"],
    "Salary": [65000, 70000,  62000, 85000]
}

df = pd.DataFrame(data)
print(df)
# Out:
#     Name  Age       City  Salary
# 0    Ram   20     Raipur   65000
# 1  Mohan   23     Bhilai   70000
# 2   Sonu   21     Jaipur   62000
# 3  Bhola   22  Rishikesh   85000

# %%
data_list = [
    ["Ram",   20,     "Raipur",   65000],
    ["Mohan" ,  23 ,    "Bhilai" ,  70000],
    ["Sonu" ,  21 ,    "Jaipur" ,  62000],
    ["Bhola" ,  22,  "Rishikesh",   85000],
]
df2 = pd.DataFrame(data_list)
head_col = ["Name","Age","City","Salary"]
df2 = pd.DataFrame(data_list, columns= head_col)
df2
# Out:
#     Name  Age       City  Salary
# 0    Ram   20     Raipur   65000
# 1  Mohan   23     Bhilai   70000
# 2   Sonu   21     Jaipur   62000
# 3  Bhola   22  Rishikesh   85000

# %%
df2[["Name","Salary"]]
# Out:
#     Name  Salary
# 0    Ram   65000
# 1  Mohan   70000
# 2   Sonu   62000
# 3  Bhola   85000

# %%
df2["Designation"] = ["Doctor", "Engineer", "CEO", "HR"]

# %%
df2
# Out:
#     Name  Age       City  Salary Designation
# 0    Ram   20     Raipur   65000      Doctor
# 1  Mohan   23     Bhilai   70000    Engineer
# 2   Sonu   21     Jaipur   62000         CEO
# 3  Bhola   22  Rishikesh   85000          HR

# %%
df2.drop("Designation", axis=1)
# Out:
#     Name  Age       City  Salary
# 0    Ram   20     Raipur   65000
# 1  Mohan   23     Bhilai   70000
# 2   Sonu   21     Jaipur   62000
# 3  Bhola   22  Rishikesh   85000

# %%
df2
# Out:
#     Name  Age       City  Salary Designation
# 0    Ram   20     Raipur   65000      Doctor
# 1  Mohan   23     Bhilai   70000    Engineer
# 2   Sonu   21     Jaipur   62000         CEO
# 3  Bhola   22  Rishikesh   85000          HR

# %%
df2.drop([0,2], axis=0)
# Out:
#     Name  Age       City  Salary
# 1  Mohan   23     Bhilai   70000
# 3  Bhola   22  Rishikesh   85000

# %%
df2
# Out:
#     Name  Age       City  Salary
# 0    Ram   20     Raipur   65000
# 1  Mohan   23     Bhilai   70000
# 2   Sonu   21     Jaipur   62000
# 3  Bhola   22  Rishikesh   85000

# %%
df2.iloc[[2,0]]
# Out:
#    Name  Age    City  Salary
# 2  Sonu   21  Jaipur   62000
# 0   Ram   20  Raipur   65000

# %%
df.loc[[0,1]][["City", "Salary"]]
# Out:
#      City  Salary
# 0  Raipur   65000
# 1  Bhilai   70000

# %%
df.loc[[2,3]][["Name", "Age"]]
# Out:
#     Name  Age
# 2   Sonu   21
# 3  Bhola   22

# %%
df2
# Out:
#     Name  Age       City  Salary
# 0    Ram   20     Raipur   65000
# 1  Mohan   23     Bhilai   70000
# 2   Sonu   21     Jaipur   62000
# 3  Bhola   22  Rishikesh   85000

# %%
df2[df2["Age"] > 21]
# Out:
#     Name  Age       City  Salary
# 1  Mohan   23     Bhilai   70000
# 3  Bhola   22  Rishikesh   85000

# %%
df2[(df2["Age"]>21) & (df2["City"] == "Rishikesh")]
# Out:
#     Name  Age       City  Salary
# 3  Bhola   22  Rishikesh   85000
